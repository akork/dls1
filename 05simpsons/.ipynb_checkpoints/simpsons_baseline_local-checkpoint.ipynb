# %% [markdown]
# ## **Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ**

# %% [markdown]
# # Путешествие по Спрингфилду.
#
#
# Сегодня вам предстоить помочь телекомпании FOX  в обработке их контента. Как вы знаете сериал Симсоны идет на телеэкранах более 25 лет и за это время скопилось очень много видео материала. Персоонажи менялись вместе с изменяющимися графическими технологиями   и Гомер 2018 не очень похож на Гомера 1989. Нашей задачей будет научиться классифицировать персонажей проживающих в Спрингфилде. Думаю, что нет смысла представлять каждого из них в отдельности.
#
#
#
#  ![alt text](https://vignette.wikia.nocookie.net/simpsons/images/5/5a/Spider_fat_piglet.png/revision/latest/scale-to-width-down/640?cb=20111118140828)

# %% [markdown]
# ### Установка зависимостей

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
display(sys.version)
sys.path
# !echo $PATH
# Out:
# '3.6.9 (default, Oct  8 2020, 12:12:24) \n[GCC 8.4.0]'
# /usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin

# %%
# !pip install -U torch torchvision
# Out:
# Requirement already up-to-date: torch in /usr/local/lib/python3.6/dist-packages (1.7.0+cu101)
# Requirement already up-to-date: torchvision in /usr/local/lib/python3.6/dist-packages (0.8.1+cu101)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied, skipping upgrade: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.3.0)

# %%
# # установка подходящей версии torch

# from os.path import exists
# from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
# platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
# print(platform)
# cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
# accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
# import torch

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
# 
# if it prints otherwise, then you need to enable GPU: 
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# нам необходима версия pillow  5.3.0
# удалим старую версию и установим новую
# !pip uninstall -y Pillow
# !pip install Pillow==5.3.0
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0
# Collecting Pillow==5.3.0
#   Using cached https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0

# %%
import PIL
print(PIL.PILLOW_VERSION)
# здесь должна быть версия 5.3.0. если это не так перехгрузите данный ноутбук:
# Menu > Runtime > Restart Runtime
# Out:
# 5.3.0

# %%
# !nvidia-smi
import torch
torch.cuda.is_available()
# Out:
# Wed Dec  2 09:01:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    32W / 149W |     11MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# True

# %% [markdown]
# В нашем тесте будет 990 картнок, для которых вам будет необходимо предсказать класс.

# %%
import pickle
import numpy as np
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

# в sklearn не все гладко, чтобы в colab удобно выводить картинки 
# мы будем игнорировать warnings
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']
# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = 224
# работаем на видеокарте
DEVICE = torch.device("cuda")

# %% [markdown]
# https://jhui.github.io/2018/02/09/PyTorch-Data-loading-preprocess_torchvision/

# %% [markdown]
# Ниже мы исспользуем враппер над датасетом для удобной работы. Вам стоит понимать, что происходит с LabelEncoder и  с torch.Transformation.
#
# ToTensor конвертирует  PIL Image с параметрами в диапазоне [0, 255] (как все пиксели) в FloatTensor размера (C x H x W) [0,1] , затем производится масштабирование:
# $input = \frac{input - \mu}{\text{standard deviation}} $, <br>       константы - средние и дисперсии по каналам на основе ImageNet
#
#
# Стоит также отметить, что мы переопределяем метод __getitem__ для удобства работы с данной структурой данных.
#  Также используется LabelEncoder для преобразования строковых меток классов в id и обратно. В описании датасета указано, что картинки разного размера, так как брались напрямую с видео, поэтому следуем привести их к одному размер (это делает метод  _prepare_sample)

# %%
class SimpsonsDataset(Dataset):
    """
    Датасет с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры
    """
    def __init__(self, files, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode

        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files)
     
        self.label_encoder = LabelEncoder()

        if self.mode != 'test':
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)

            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)
                      
    def __len__(self):
        return self.len_
      
    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image
  
    def __getitem__(self, index):
        print(f'getting item {index}')
        # для преобразования изображений в тензоры PyTorch и нормализации входа
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
        ])
        x = self.load_sample(self.files[index])
        x = self._prepare_sample(x)
        x = np.array(x / 255, dtype='float32')
        x = transform(x)
        if self.mode == 'test':
            return x
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()
            return x, y
        
    def _prepare_sample(self, image):
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return np.array(image)

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %%
wd = '/content/drive/MyDrive/dls1/05simpsons/'
TRAIN_DIR = Path(wd + 'trainset')
TEST_DIR = Path(wd + 'testset')
print(type(TRAIN_DIR))
print(TRAIN_DIR)

train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))
# Out:
# <class 'pathlib.PosixPath'>
# /content/drive/MyDrive/dls1/05simpsons/trainset

# %%
x = np.array(Image.open(next(iter(train_val_files))).resize((RESCALE_SIZE, RESCALE_SIZE)))
y = np.array(x / 255, np.float32)
# print(x)
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
])
x = transform(x)
y = transform(y)
type(x)
print(x.size())
print(x.shape)
print(np.prod(x.shape))
print(3 * 224 * 224)
out = nn.Linear(np.prod(x.shape), 5)
x = x.view((x.size(0), -1))
print(x.dim())
print(x.shape)
# x = Variable(x)
out.forward(x)
# Out:
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# 150528
# 150528
# 2
# torch.Size([3, 50176])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-7bcbbdc64daa> in <module>()
#      18 print(x.shape)
#      19 # x = Variable(x)
# ---> 20 out.forward(x)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (3x50176 and 150528x5)

# %%
from sklearn.model_selection import train_test_split

train_val_labels = [path.parent.name for path in train_val_files]

train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)
print(len(val_files))
print(len(train_files))
print(type(next(iter(val_files))))
# Out:
# 5232
# 15694
# <class 'pathlib.PosixPath'>

# %%
val_dataset = SimpsonsDataset(val_files, mode='val')

# %%
np.random.seed(42)
idx = np.random.randint(0, 1000)
print(idx)
sample, sample_y = val_dataset[idx]
print(sample.min(), sample.max())
print(sample)
# Out:
# 102
# getting item 102
# tensor(-2.1179) tensor(2.6400)
# tensor([[[ 1.0159,  1.0159,  1.0159,  ...,  0.6734,  0.6734,  0.6734],
#          [ 1.0159,  1.0159,  1.0159,  ...,  0.6734,  0.6734,  0.6734],
#          [ 1.0159,  1.0159,  1.0159,  ...,  0.6734,  0.6734,  0.6734],
#          ...,
#          [-0.9877, -0.9877, -0.9877,  ..., -0.9192, -0.9192, -0.9192],
#          [-1.3130, -1.3130, -1.3130,  ..., -1.0048, -1.0048, -1.0048],
#          [-0.5424, -0.5424, -0.5424,  ..., -0.6452, -0.6452, -0.6452]],
#
#         [[-0.6001, -0.6001, -0.6001,  ..., -0.9503, -0.9503, -0.9503],
#          [-0.6001, -0.6001, -0.6001,  ..., -0.9503, -0.9503, -0.9503],
#          [-0.6001, -0.6001, -0.6001,  ..., -0.9503, -0.9503, -0.9503],
#          ...,
#          [-1.8782, -1.8782, -1.8782,  ..., -1.9482, -1.9482, -1.9482],
#          [-1.9307, -1.9307, -1.9307,  ..., -2.0357, -2.0357, -2.0357],
#          [-1.8081, -1.8081, -1.8081,  ..., -1.7556, -1.7556, -1.7556]],
#
#         [[-0.1312, -0.1312, -0.1312,  ..., -0.4101, -0.4101, -0.4101],
#          [-0.1312, -0.1312, -0.1312,  ..., -0.4101, -0.4101, -0.4101],
#          [-0.1312, -0.1312, -0.1312,  ..., -0.4101, -0.4101, -0.4101],
#          ...,
#          [-1.7696, -1.7696, -1.7696,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.6999, -1.6999, -1.6999,  ..., -1.6999, -1.6999, -1.6999]]])

# %%
# uncomment if you have problem with pillow
def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
Image.register_extension = register_extension
def register_extensions(id, extensions): 
    for extension in extensions: register_extension(id, extension)
Image.register_extensions = register_extensions

# %% [markdown]
# Давайте посмотрим на наших героев внутри датасета.

# %%
fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(8, 8), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    # random_characters = int(np.random.uniform(0,1000))
    random_characters = np.random.randint(0,1000)
    # np.random.int()
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
# Out:
# getting item 435
# getting item 860
# getting item 270
# getting item 106
# getting item 71
# getting item 700
# getting item 20
# getting item 614
# getting item 121

# %% [markdown]
# Можете добавить ваши любимые сцены и классифицировать их. (веселые результаты можно кидать в чат)

# %% [markdown]
# ### Построение нейросети
#
# Запустить данную сеть будет вашим мини-заданием на первую неделю, чтобы было проще участвовать в соревновании.
#
# Данная архитектура будет очень простой и нужна для того, чтобы установить базовое понимание и получить простенький сабмит на Kaggle
#
# <!-- Здесь вам предлагается дописать сверточную сеть глубины 4/5.  -->
#
# *Описание слоев*:
#
#
#
# 1. размерность входа: 3x224x224
# 2.размерности после слоя:  8x111x111
# 3. 16x54x54
# 4. 32x26x26
# 5. 64x12x12
# 6. выход: 96x5x5

# %%
# Очень простая сеть
class SimpleCnn(nn.Module):
  
    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        
        self.out = nn.Linear(96 * 5 * 5, n_classes)
  
  
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits

# %%
def fit_epoch(model, train_loader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0

    with tqdm(desc="epoch", total=) as pbar_outer:
      for inputs, labels in train_loader:
          total += itputs.shape[0]
          inputs = inputs.to(DEVICE) 
          labels = labels.to(DEVICE)
          
          n_samples = inputs.size(0)
          
          #clear grad
          optimizer.zero_grad()

          #forward
          outputs = model(inputs)
          loss = criterion(outputs, labels)
          
          #backward
          loss.backward()
          
          #step
          optimizer.step()
          
          # loss
          running_loss += loss.item() * n_samples
          
          # accuracy
          preds = torch.argmax(outputs, 1)
          running_corrects += torch.sum(preds == labels.data) # accuracy
          
          # for mean loss and accuracy total number of samples in the epoch needed
          processed_data += n_samples
              
    train_loss = running_loss / processed_data
    train_acc = running_corrects.cpu().numpy() / processed_data
    return train_loss, train_acc

# %%
def eval_epoch(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    return val_loss, val_acc

# %%
def train(train_files, val_files, model, epochs, batch_size):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

     with tqdm(desc="epoch", total=epochs) as pbar_outer:
        opt = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, opt)
            print("loss", train_loss)
            
            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            history.append((train_loss, train_acc, val_loss, val_acc))
            
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
    return history

# %%
def predict(model, test_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
DEVICE = torch.device("cuda")
n_classes = len(np.unique(train_val_labels))
simple_cnn = SimpleCnn(n_classes).to(DEVICE)
print("we will classify :{}".format(n_classes))
print(simple_cnn)
# Out:
# we will classify :42
# SimpleCnn(
#   (conv1): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=2400, out_features=42, bias=True)
# )

# %% [markdown]
# Запустим обучение сети.

# %%
if val_dataset is None:
    val_dataset = SimpsonsDataset(val_files, mode='val')
    
train_dataset = SimpsonsDataset(train_files, mode='train')

# %%
history = train(train_dataset, val_dataset, model=simple_cnn, epochs=2, batch_size=64)
# Out:
# epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# getting item 12230
# getting item 5205
# getting item 13677
# getting item 2978
# getting item 3587
# getting item 10862
# getting item 8509
# getting item 6576
# getting item 8661
# getting item 45
# getting item 1817
# getting item 4769
# getting item 671
# getting item 10837
# getting item 614
# getting item 8991
# getting item 6013
# getting item 12380
# getting item 12492
# getting item 15238
# getting item 1586
# getting item 6940
# getting item 7459
# getting item 2572
# getting item 10918
# getting item 6941
# getting item 7384
# getting item 2490
# getting item 3119
# getting item 8203
# getting item 10903
# getting item 12910
# getting item 2601
# getting item 549
# getting item 1837
# getting item 13787
# getting item 4927
# getting item 12311
# getting item 14097
# getting item 14992
# getting item 259
# getting item 1854
# getting item 6639
# getting item 12809
# getting item 8912
# getting item 11715
# getting item 13901
# getting item 2977
# getting item 5075
# getting item 7499
# getting item 3252
# getting item 3
# getting item 4793
# getting item 12150
# getting item 15504
# getting item 7823
# getting item 7030
# getting item 3603
# getting item 2987
# getting item 1248
# getting item 1507
# getting item 10412
# getting item 4871
# getting item 6374
# getting item 6347
# getting item 6155
# getting item 6584
# getting item 4026
# getting item 4449
# getting item 8469
# getting item 10192
# getting item 11296
# getting item 10896
# getting item 14953
# getting item 1681
# getting item 9912
# getting item 12254
# getting item 563
# getting item 15529
# getting item 15217
# getting item 15621
# getting item 2366
# getting item 9755
# getting item 11838
# getting item 8266
# getting item 2267
# getting item 8359
# getting item 840
# getting item 8729
# getting item 10501
# getting item 2015
# getting item 2318
# getting item 12593
# getting item 11072
# getting item 2233
# getting item 15047
# getting item 12021
# getting item 1821
# getting item 3963
# getting item 11635
# getting item 385
# getting item 10283
# getting item 14429
# getting item 2564
# getting item 937
# getting item 7335
# getting item 7973
# getting item 3940
# getting item 12364
# getting item 7391
# getting item 10075
# getting item 13073
# getting item 7783
# getting item 178
# getting item 9745
# getting item 6414
# getting item 14449
# getting item 6596
# getting item 14197
# getting item 11978
# getting item 2345
# getting item 8063
# getting item 8147
# getting item 503
# getting item 9750
# getting item 13463
# getting item 6398
# getting item 14374
# getting item 6670
# getting item 12352
# getting item 4089
# getting item 525
# getting item 4960
# getting item 3773
# getting item 6484
# getting item 1247
# getting item 254
# getting item 13167
# getting item 4472
# getting item 14440
# getting item 210
# getting item 8185
# getting item 13604
# getting item 8318
# getting item 2944
# getting item 2539
# getting item 7117
# getting item 9138
# getting item 11995
# getting item 6060
# getting item 11248
# getting item 14947
# getting item 7944
# getting item 5226
# getting item 3437
# getting item 2826
# getting item 7465
# getting item 15619
# getting item 8797
# getting item 3684
# getting item 2289
# getting item 842
# getting item 11080
# getting item 15119
# getting item 14386
# getting item 5565
# getting item 14878
# getting item 3841
# getting item 11213
# getting item 3022
# getting item 10276
# getting item 13555
# getting item 1945
# getting item 10650
# getting item 12
# getting item 652
# getting item 6420
# getting item 5252
# getting item 2933
# getting item 10251
# getting item 11128
# getting item 5494
# getting item 12585
# getting item 15141
# getting item 11300
# getting item 9561
# getting item 10471
# getting item 8560
# getting item 3623
# getting item 15135
# getting item 4893
# getting item 4252
# getting item 3849
# getting item 461
# getting item 10736
# getting item 67
# getting item 1125
# getting item 2118
# getting item 6372
# getting item 3760
# getting item 6053
# getting item 4728
# getting item 9822
# getting item 13586
# getting item 1101
# getting item 14312
# getting item 13084
# getting item 8744
# getting item 1568
# getting item 13783
# getting item 10110
# getting item 4009
# getting item 8241
# getting item 864
# getting item 7600
# getting item 5914
# getting item 14016
# getting item 9707
# getting item 14754
# getting item 5161
# getting item 10064
# getting item 3889
# getting item 6723
# getting item 5250
# getting item 10881
# getting item 8350
# getting item 8265
# getting item 4679
# getting item 13739
# getting item 11791
# getting item 7946
# getting item 11543
# getting item 310
# getting item 10346
# getting item 4338
# getting item 6698
# getting item 4924
# getting item 1910
# getting item 13881
# getting item 3479
# getting item 3334
# getting item 13200
# getting item 1403
# getting item 7791
# getting item 10872
# getting item 15252
# getting item 1160
# getting item 14059
# getting item 6373
# getting item 9595
# getting item 564
# getting item 8755
# getting item 5865
# getting item 15357
# getting item 2499
# getting item 11618
# getting item 12958
# getting item 9195
# getting item 14286
# getting item 7324
# getting item 5003
# getting item 13416
# getting item 9840
# getting item 8263
# getting item 4703
# getting item 2581
# getting item 1664
# getting item 5501
# getting item 4849
# getting item 14523
# getting item 11905
# getting item 2116
# getting item 13906
# getting item 2093
# getting item 3135
# getting item 12746
# getting item 14856
# getting item 4583
# getting item 2874
# getting item 7113
# getting item 6522
# getting item 7273
# getting item 5560
# getting item 8442
# getting item 12768
# getting item 15526
# getting item 10024
# getting item 2162
# getting item 6852
# getting item 13407
# getting item 769
# getting item 3659
# getting item 10334
# getting item 8521
# getting item 11868
# getting item 10797
# getting item 4040
# getting item 2512
# getting item 2521
# getting item 8584
# getting item 12914
# getting item 610
# getting item 10296
# getting item 1686
# getting item 1695
# getting item 11331
# getting item 9854
# getting item 641
# getting item 15058
# getting item 4027
# getting item 15434
# getting item 6621
# getting item 14003
# getting item 9875
# getting item 8935
# getting item 12604
# getting item 11709
# getting item 82
# getting item 4880
# getting item 10629
# getting item 1495
# getting item 6864
# getting item 15108
# getting item 10063
# getting item 9058
# getting item 10522
# getting item 3540
# getting item 8840
# getting item 7207
# getting item 6211
# getting item 7249
# getting item 5625
# getting item 1349
# getting item 6850
# getting item 12645
# getting item 3828
# getting item 7174
# getting item 4193
# getting item 2465
# getting item 611
# getting item 76
# getting item 287
# getting item 1663
# getting item 5345
# getting item 1405
# getting item 7490
# getting item 9372
# getting item 10515
# getting item 7666
# getting item 10476
# getting item 946
# getting item 12158
# getting item 8371
# getting item 1982
# getting item 15359
# getting item 5458
# getting item 460
# getting item 7007
# getting item 539
# getting item 1647
# getting item 8605
# getting item 11544
# getting item 5989
# getting item 11687
# getting item 8687
# getting item 4586
# getting item 14901
# getting item 14844
# getting item 6502
# getting item 124
# getting item 5094
# getting item 4465
# getting item 6033
# getting item 7587
# getting item 4207
# getting item 9198
# getting item 7819
# getting item 6146
# getting item 11950
# getting item 2311
# getting item 854
# getting item 15679
# getting item 5644
# getting item 5454
# getting item 322
# getting item 9413
# getting item 7929
# getting item 9512
# getting item 10435
# getting item 12603
# getting item 11349
# getting item 5637
# getting item 14651
# getting item 430
# getting item 4077
# getting item 1500
# getting item 668
# getting item 11144
# getting item 12474
# getting item 4861
# getting item 905
# getting item 10912
# getting item 5995
# getting item 11008
# getting item 10149
# getting item 9476
# getting item 7368
# getting item 4904
# getting item 8356
# getting item 13366
# getting item 9226
# getting item 3842
# getting item 4468
# getting item 9534
# getting item 13625
# getting item 6115
# getting item 14196
# getting item 9050
# getting item 19
# getting item 15123
# getting item 794
# getting item 6641
# getting item 83
# getting item 11239
# getting item 5773
# getting item 9064
# getting item 13794
# getting item 3229
# getting item 14502
# getting item 13445
# getting item 13991
# getting item 14770
# getting item 2057
# getting item 10179
# getting item 14424
# getting item 11594
# getting item 14924
# getting item 3952
# getting item 8861
# getting item 6875
# getting item 1764
# getting item 7957
# getting item 15149
# getting item 7575
# getting item 14455
# getting item 5753
# getting item 355
# getting item 5620
# getting item 14130
# getting item 6792
# getting item 4685
# getting item 1595
# getting item 8779
# getting item 4979
# getting item 179
# getting item 15201
# getting item 2543
# getting item 8303
# getting item 226
# getting item 14033
# getting item 11710
# getting item 4246
# getting item 4819
# getting item 13181
# getting item 1694
# getting item 14531
# getting item 9842
# getting item 12658
# getting item 9329
# getting item 624
# getting item 7074
# getting item 3245
# getting item 6184
# getting item 13246
# getting item 4296
# getting item 9984
# getting item 6500
# getting item 6574
# getting item 12917
# getting item 7874
# getting item 4888
# getting item 15448
# getting item 8463
# getting item 13574
# getting item 2404
# getting item 5163
# getting item 3390
# getting item 15112
# getting item 1269
# getting item 5286
# getting item 3433
# getting item 7129
# getting item 12550
# getting item 5803
# getting item 8886
# getting item 1003
# getting item 10825
# getting item 7788
# getting item 7338
# getting item 8043
# getting item 4457
# getting item 6011
# getting item 6934
# getting item 7643
# getting item 12385
# getting item 4654
# getting item 1643
# getting item 11723
# getting item 6413
# getting item 4394
# getting item 9267
# getting item 6369
# getting item 13258
# getting item 13129
# getting item 4932
# getting item 2377
# getting item 2121
# getting item 1897
# getting item 3360
# getting item 14864
# getting item 1499
# getting item 11418
# getting item 12374
# getting item 4567
# getting item 14733
# getting item 443
# getting item 15674
# getting item 3905
# getting item 1190
# getting item 13885
# getting item 2916
# getting item 2724
# getting item 5488
# getting item 11686
# getting item 1337
# getting item 6819
# getting item 6845
# getting item 12533
# getting item 7158
# getting item 10782
# getting item 12291
# getting item 1719
# getting item 5270
# getting item 11489
# getting item 15006
# getting item 7681
# getting item 10157
# getting item 10652
# getting item 808
# getting item 14863
# getting item 1711
# getting item 9746
# getting item 2193
# getting item 10871
# getting item 1107
# getting item 10534
# getting item 13313
# getting item 357
# getting item 11468
# getting item 15167
# getting item 12957
# getting item 6126
# getting item 9298
# getting item 5128
# getting item 13193
# getting item 5519
# getting item 1898
# getting item 2231
# getting item 222
# getting item 15649
# getting item 10460
# getting item 10164
# getting item 6158
# getting item 6128
# getting item 3898
# getting item 7252
# getting item 10331
# getting item 13966
# getting item 12392
# getting item 7817
# getting item 11167
# getting item 5944
# getting item 1291
# getting item 14402
# getting item 5599
# getting item 968
# getting item 9519
# getting item 11523
# getting item 9518
# getting item 15315
# getting item 3745
# getting item 6607
# getting item 7161
# getting item 1498
# getting item 11676
# getting item 1959
# getting item 9737
# getting item 6245
# getting item 2817
# getting item 9146
# getting item 13729
# getting item 10338
# getting item 1073
# getting item 6863
# getting item 10402
# getting item 10320
# getting item 15188
# getting item 4999
# getting item 11041
# getting item 570
# getting item 6139
# getting item 12767
# getting item 14218
# getting item 2316
# getting item 12090
# getting item 1300
# getting item 12180
# getting item 2454
# getting item 1917
# getting item 12336
# getting item 6629
# getting item 4779
# getting item 8852
# getting item 4803
# getting item 5903
# getting item 10176
# getting item 522
# getting item 8109
# getting item 11034
# getting item 10849
# getting item 4117
# getting item 12199
# getting item 8407
# getting item 10550
# getting item 9860
# getting item 3604
# getting item 7044
# getting item 7538
# getting item 15682
# getting item 10302
# getting item 1684
# getting item 11565
# getting item 8800
# getting item 4993
# getting item 12265
# getting item 15335
# getting item 8766
# getting item 11123
# getting item 8264
# getting item 10165
# getting item 11948
# getting item 8519
# getting item 9841
# getting item 14782
# getting item 14647
# getting item 12838
# getting item 9015
# getting item 3532
# getting item 15665
# getting item 11082
# getting item 8760
# getting item 10072
# getting item 3527
# getting item 7766
# getting item 14341
# getting item 10454
# getting item 15181
# getting item 1404
# getting item 8224
# getting item 9876
# getting item 8487
# getting item 11273
# getting item 12316
# getting item 10180
# getting item 11352
# getting item 11196
# getting item 14074
# getting item 8742
# getting item 8456
# getting item 8592
# getting item 15244
# getting item 11452
# getting item 12844
# getting item 10767
# getting item 10620
# getting item 12325
# getting item 11211
# getting item 1199
# getting item 9028
# getting item 3030
# getting item 15085
# getting item 7991
# getting item 13489
# getting item 6575
# getting item 5678
# getting item 1722
# getting item 8854
# getting item 9788
# getting item 11460
# getting item 11297
# getting item 3675
# getting item 11267
# getting item 3666
# getting item 11070
# getting item 8838
# getting item 7628
# getting item 1958
# getting item 12221
# getting item 15262
# getting item 14047
# getting item 3552
# getting item 5891
# getting item 12555
# getting item 14411
# getting item 3318
# getting item 4706
# getting item 2480
# getting item 14120
# getting item 10820
# getting item 12616
# getting item 1761
# getting item 1603
# getting item 388
# getting item 5258
# getting item 6783
# getting item 6130
# getting item 7306
# getting item 631
# getting item 657
# getting item 13240
# getting item 12112
# getting item 9068
# getting item 14650
# getting item 6877
# getting item 9204
# getting item 2062
# getting item 1727
# getting item 13213
# getting item 761
# getting item 8215
# getting item 3744
# getting item 11498
# getting item 9895
# getting item 1532
# getting item 6956
# getting item 298
# getting item 14718
# getting item 10002
# getting item 3975
# getting item 7746
# getting item 14608
# getting item 9125
# getting item 1271
# getting item 4512
# getting item 2260
# getting item 7861
# getting item 387
# getting item 1453
# getting item 432
# getting item 14236
# getting item 11353
# getting item 5220
# getting item 6443
# getting item 2932
# getting item 31
# getting item 4525
# getting item 10433
# getting item 15483
# getting item 15408
# getting item 11506
# getting item 8084
# getting item 12554
# getting item 5264
# getting item 5355
# getting item 3248
# getting item 6930
# getting item 6831
# getting item 13107
# getting item 2274
# getting item 4256
# getting item 3574
# getting item 5579
# getting item 13503
# getting item 1423
# getting item 5969
# getting item 3368
# getting item 7175
# getting item 10382
# getting item 8495
# getting item 2179
# getting item 3100
# getting item 6395
# getting item 11318
# getting item 13954
# getting item 4566
# getting item 15599
# getting item 620
# getting item 4103
# getting item 10480
# getting item 1720
# getting item 11181
# getting item 6549
# getting item 1992
# getting item 3657
# getting item 3291
# getting item 3421
# getting item 52
# getting item 2692
# getting item 12322
# getting item 9073
# getting item 12076
# getting item 7403
# getting item 8370
# getting item 13311
# getting item 3911
# getting item 6083
# getting item 2159
# getting item 1815
# getting item 212
# getting item 2143
# getting item 8699
# getting item 12951
# getting item 6545
# getting item 10947
# getting item 6789
# getting item 6376
# getting item 8103
# getting item 8339
# getting item 9438
# getting item 5332
# getting item 14205
# getting item 2264
# getting item 2587
# getting item 9366
# getting item 13685
# getting item 4666
# getting item 7892
# getting item 7395
# getting item 14075
# getting item 1047
# getting item 10380
# getting item 7646
# getting item 3088
# getting item 5426
# getting item 3866
# getting item 5895
# getting item 14781
# getting item 8879
# getting item 6093
# getting item 7094
# getting item 10498
# getting item 8708
# getting item 4691
# getting item 2463
# getting item 4947
# getting item 7605
# getting item 1731
# getting item 3503
# getting item 5064
# getting item 8498
# getting item 10780
# getting item 2325
# getting item 1666
# getting item 9487
# getting item 9644
# getting item 2884
# getting item 2017
# getting item 9615
# getting item 5514
# getting item 13077
# getting item 14044
# getting item 3506
# getting item 4025
# getting item 4044
# getting item 38
# getting item 15634
# getting item 2462
# getting item 2350
# getting item 15523
# getting item 4470
# getting item 4921
# getting item 10233
# getting item 12930
# getting item 2926
# getting item 7894
# getting item 2476
# getting item 3408
# getting item 3556
# getting item 10702
# getting item 4083
# getting item 3454
# getting item 755
# getting item 8451
# getting item 7784
# getting item 4507
# getting item 6752
# getting item 6071
# getting item 4665
# getting item 9206
# getting item 12057
# getting item 7593
# getting item 2617
# getting item 8322
# getting item 15500
# getting item 14321
# getting item 944
# getting item 13874
# getting item 172
# getting item 10875
# getting item 7633
# getting item 8735
# getting item 10186
# getting item 4614
# getting item 13
# getting item 5327
# getting item 5653
# getting item 9940
# getting item 15218
# getting item 8529
# getting item 13304
# getting item 3917
# getting item 345
# getting item 6435
# getting item 5740
# getting item 10466
# getting item 14465
# getting item 9889
# getting item 9920
# getting item 632
# getting item 8969
# getting item 3223
# getting item 5836
# getting item 13693
# getting item 12543
# getting item 10997
# getting item 3137
# getting item 6152
# getting item 4877
# getting item 13554
# getting item 12479
# getting item 2293
# getting item 7660
# getting item 7748
# getting item 5977
# getting item 523
# getting item 4106
# getting item 10606
# getting item 2737
# getting item 14994
# getting item 6026
# getting item 11515
# getting item 8608
# getting item 11132
# getting item 1210
# getting item 4157
# getting item 5127
# getting item 10436
# getting item 10895
# getting item 7154
# getting item 7388
# getting item 4835
# getting item 14303
# getting item 3505
# getting item 2354
# getting item 12028
# getting item 11051
# getting item 11492
# getting item 2573
# getting item 3719
# getting item 9079
# getting item 6665
# getting item 5626
# getting item 13921
# getting item 9963
# getting item 11190
# getting item 3716
# getting item 1644
# getting item 11046
# getting item 910
# getting item 10795
# getting item 11291
# getting item 9027
# getting item 11738
# getting item 12471
# getting item 10956
# getting item 7875
# getting item 11221
# getting item 1202
# getting item 653
# getting item 10219
# getting item 51
# getting item 11602
# getting item 1146
# getting item 4845
# getting item 10996
# getting item 13736
# getting item 9162
# getting item 5665
# getting item 12687
# getting item 3810
# getting item 1447
# getting item 14492
# getting item 5225
# getting item 5357
# getting item 658
# getting item 11533
# getting item 1981
# getting item 8183
# getting item 11673
# getting item 4384
# getting item 2135
# getting item 14092
# getting item 1407
# getting item 13916
# getting item 12081
# getting item 10479
# getting item 10965
# getting item 8182
# getting item 4132
# getting item 6645
# getting item 10889
# getting item 12037
# getting item 1294
# getting item 7425
# getting item 14266
# getting item 11769
# getting item 6497
# getting item 7275
# getting item 13723
# getting item 8244
# getting item 5877
# getting item 14883
# getting item 1192
# getting item 11741
# getting item 10513
# getting item 12155
# getting item 13477
# getting item 5981
# getting item 6822
# getting item 4159
# getting item 4742
# getting item 14654
# getting item 3758
# getting item 15032
# getting item 9785
# getting item 321
# getting item 13532
# getting item 4146
# getting item 9593
# getting item 8649
# getting item 6836
# getting item 10177
# getting item 11983
# getting item 6778
# getting item 15393
# getting item 11120
# getting item 7066
# getting item 12282
# getting item 8434
# getting item 7697
# getting item 7166
# getting item 12494
# getting item 15310
# getting item 15203
# getting item 636
# getting item 7755
# getting item 1996
# getting item 12098
# getting item 8954
# getting item 7261
# getting item 7951
# getting item 12738
# getting item 7963
# getting item 4442
# getting item 2247
# getting item 11187
# getting item 5964
# getting item 12121
# getting item 6192
# getting item 9928
# getting item 3061
# getting item 3711
# getting item 10844
# getting item 10645
# getting item 11384
# getting item 5256
# getting item 10850
# getting item 11216
# getting item 4239
# getting item 13692
# getting item 4048
# getting item 7554
# getting item 8847
# getting item 2107
# getting item 14073
# getting item 4095
# getting item 2051
# getting item 8250
# getting item 4883
# getting item 4916
# getting item 4432
# getting item 3895
# getting item 13201
# getting item 90
# getting item 8053
# getting item 15309
# getting item 14175
# getting item 4004
# getting item 15014
# getting item 4937
# getting item 10390
# getting item 13715
# getting item 3332
# getting item 9590
# getting item 15089
# getting item 4185
# getting item 9200
# getting item 6984
# getting item 8229
# getting item 1095
# getting item 7498
# getting item 14560
# getting item 5846
# getting item 10285
# getting item 13122
# getting item 8620
# getting item 13973
# getting item 5243
# getting item 4236
# getting item 11979
# getting item 15481
# getting item 10672
# getting item 4936
# getting item 9784
# getting item 10737
# getting item 12273
# getting item 1457
# getting item 2602
# getting item 13635
# getting item 13226
# getting item 3615
# getting item 4671
# getting item 6797
# getting item 1425
# getting item 11844
# getting item 14751
# getting item 7233
# getting item 6826
# getting item 1477
# getting item 1709
# getting item 2042
# getting item 7654
# getting item 11879
# getting item 13735
# getting item 13253
# getting item 1515
# getting item 12726
# getting item 6805
# getting item 6543
# getting item 14602
# getting item 10654
# getting item 15033
# getting item 10697
# getting item 11819
# getting item 1067
# getting item 9817
# getting item 7889
# getting item 12792
# getting item 8237
# getting item 2947
# getting item 13485
# getting item 8530
# getting item 7375
# getting item 14952
# getting item 9620
# getting item 10792
# getting item 6715
# getting item 7228
# getting item 15639
# getting item 10971
# getting item 10127
# getting item 9248
# getting item 15693
# getting item 8622
# getting item 7311
# getting item 2148
# getting item 7960
# getting item 5107
# getting item 10452
# getting item 3964
# getting item 1624
# getting item 3901
# getting item 8875
# getting item 4339
# getting item 7504
# getting item 2429
# getting item 892
# getting item 9076
# getting item 14791
# getting item 5462
# getting item 10357
# getting item 11947
# getting item 2043
# getting item 3372
# getting item 3872
# getting item 15484
# getting item 4363
# getting item 8126
# getting item 11067
# getting item 4941
# getting item 7956
# getting item 4844
# getting item 12061
# getting item 3336
# getting item 10680
# getting item 2973
# getting item 10941
# getting item 15336
# getting item 1700
# getting item 7099
# getting item 1253
# getting item 12258
# getting item 11691
# getting item 1065
# getting item 277
# getting item 8025
# getting item 9507
# getting item 13288
# getting item 9462
# getting item 13127
# getting item 1180
# getting item 12595
# getting item 7569
# getting item 13126
# getting item 7147
# getting item 7895
# getting item 10418
# getting item 10638
# getting item 602
# getting item 8255
# getting item 5037
# getting item 4674
# getting item 3943
# getting item 11214
# getting item 7639
# getting item 5041
# getting item 12752
# getting item 13447
# getting item 10980
# getting item 2966
# getting item 10310
# getting item 2101
# getting item 11638
# getting item 7632
# getting item 4487
# getting item 11303
# getting item 4912
# getting item 4020
# getting item 13780
# getting item 11998
# getting item 5356
# getting item 13460
# getting item 15677
# getting item 13585
# getting item 11091
# getting item 1693
# getting item 891
# getting item 3008
# getting item 4736
# getting item 14717
# getting item 10812
# getting item 8411
# getting item 599
# getting item 8808
# getting item 7374
# getting item 8857
# getting item 2889
# getting item 10345
# getting item 14914
# getting item 10571
# getting item 6079
# getting item 14958
# getting item 3676
# getting item 9216
# getting item 3122
# getting item 5407
# getting item 15303
# getting item 2190
# getting item 8239
# getting item 2206
# getting item 9887
# getting item 519
# getting item 2203
# getting item 2105
# getting item 14833
# getting item 13822
# getting item 10458
# getting item 3671
# getting item 7431
# getting item 7810
# getting item 7741
# getting item 9594
# getting item 8903
# getting item 11949
# getting item 6636
# getting item 1105
# getting item 4225
# getting item 9900
# getting item 10438
# getting item 8680
# getting item 13856
# getting item 11810
# getting item 10301
# getting item 12536
# getting item 4745
# getting item 6242
# getting item 3106
# getting item 9170
# getting item 7453
# getting item 12561
# getting item 8536
# getting item 6858
# getting item 6114
# getting item 13120
# getting item 12228
# getting item 317
# getting item 8476
# getting item 1868
# getting item 5794
# getting item 3262
# getting item 12872
# getting item 6368
# getting item 2059
# getting item 15383
# getting item 6261
# getting item 1598
# getting item 13160
# getting item 2342
# getting item 5617
# getting item 2176
# getting item 8814
# getting item 4283
# getting item 6870
# getting item 12465
# getting item 11809
# getting item 2337
# getting item 4450
# getting item 6793
# getting item 14552
# getting item 12925
# getting item 9675
# getting item 9677
# getting item 11255
# getting item 4669
# getting item 14984
# getting item 2132
# getting item 3147
# getting item 6285
# getting item 5601
# getting item 8170
# getting item 15514
# getting item 7930
# getting item 1931
# getting item 1392
# getting item 861
# getting item 8482
# getting item 497
# getting item 2248
# getting item 12664
# getting item 5093
# getting item 687
# getting item 812
# getting item 12194
# getting item 7997
# getting item 5048
# getting item 11779
# getting item 6272
# getting item 2355
# getting item 13749
# getting item 6950
# getting item 2795
# getting item 14484
# getting item 1302
# getting item 2928
# getting item 15264
# getting item 3925
# getting item 14041
# getting item 5889
# getting item 1841
# getting item 14169
# getting item 7318
# getting item 10561
# getting item 13725
# getting item 6391
# getting item 14027
# getting item 14155
# getting item 7210
# getting item 10227
# getting item 9762
# getting item 4002
# getting item 11909
# getting item 11997
# getting item 12128
# getting item 583
# getting item 13880
# getting item 8589
# getting item 12186
# getting item 7598
# getting item 11104
# getting item 2728
# getting item 6967
# getting item 9018
# getting item 7968
# getting item 12016
# getting item 1640
# getting item 7173
# getting item 1772
# getting item 2380
# getting item 4644
# getting item 7021
# getting item 1143
# getting item 11462
# getting item 145
# getting item 125
# getting item 13267
# getting item 4368
# getting item 13128
# getting item 3592
# getting item 14487
# getting item 15610
# getting item 8940
# getting item 6360
# getting item 9682
# getting item 4696
# getting item 5911
# getting item 13382
# getting item 9002
# getting item 7187
# getting item 2416
# getting item 12175
# getting item 2739
# getting item 1097
# getting item 844
# getting item 4012
# getting item 4559
# getting item 1486
# getting item 13069
# getting item 9087
# getting item 10370
# getting item 9496
# getting item 1200
# getting item 10026
# getting item 4281
# getting item 15237
# getting item 15220
# getting item 3145
# getting item 10101
# getting item 14456
# getting item 8155
# getting item 12894
# getting item 5805
# getting item 8520
# getting item 1417
# getting item 4615
# getting item 5905
# getting item 419
# getting item 8130
# getting item 15473
# getting item 12487
# getting item 4367
# getting item 14840
# getting item 881
# getting item 9870
# getting item 5385
# getting item 11527
# getting item 11169
# getting item 7512
# getting item 4360
# getting item 7673
# getting item 5694
# getting item 4852
# getting item 3986
# getting item 11308
# getting item 3250
# getting item 3074
# getting item 3670
# getting item 9404
# getting item 3965
# getting item 4494
# getting item 15246
# getting item 9547
# getting item 269
# getting item 877
# getting item 99
# getting item 2040
# getting item 10757
# getting item 10264
# getting item 7312
# getting item 2236
# getting item 15604
# getting item 9302
# getting item 1530
# getting item 9263
# getting item 9040
# getting item 3580
# getting item 4240
# getting item 7822
# getting item 9655
# getting item 6561
# getting item 5522
# getting item 14170
# getting item 3731
# getting item 9175
# getting item 10647
# getting item 14847
# getting item 12420
# getting item 10492
# getting item 1061
# getting item 1874
# getting item 7808
# getting item 14828
# getting item 3165
# getting item 4377
# getting item 5682
# getting item 14463
# getting item 10070
# getting item 10198
# getting item 14309
# getting item 13424
# getting item 5359
# getting item 8845
# getting item 4237
# getting item 4865
# getting item 10265
# getting item 4303
# getting item 3633
# getting item 10249
# getting item 9389
# getting item 9555
# getting item 1809
# getting item 3989
# getting item 7241
# getting item 6214
# getting item 13174
# getting item 11839
# getting item 6333
# getting item 7081
# getting item 6944
# getting item 1116
# getting item 11049
# getting item 9019
# getting item 5507
# getting item 5295
# getting item 15416
# getting item 5807
# getting item 9767
# getting item 11380
# getting item 6595
# getting item 13876
# getting item 7302
# getting item 3468
# getting item 8208
# getting item 12750
# getting item 7514
# getting item 13330
# getting item 10693
# getting item 5228
# getting item 8678
# getting item 4137
# getting item 6983
# getting item 10204
# getting item 8388
# getting item 13578
# getting item 13063
# getting item 1063
# getting item 6217
# getting item 14308
# getting item 14244
# getting item 843
# getting item 11524
# getting item 572
# getting item 11795
# getting item 7821
# getting item 97
# getting item 2474
# getting item 6428
# getting item 1372
# getting item 3445
# getting item 1721
# getting item 7352
# getting item 10132
# getting item 14600
# getting item 2492
# getting item 6447
# getting item 1775
# getting item 6916
# getting item 11564
# getting item 11222
# getting item 10218
# getting item 2707
# getting item 7773
# getting item 11574
# getting item 3438
# getting item 3476
# getting item 5933
# getting item 4529
# getting item 6145
# getting item 8660
# getting item 13329
# getting item 11247
# getting item 10381
# getting item 10763
# getting item 7684
# getting item 15034
# getting item 13697
# getting item 5757
# getting item 5614
# getting item 5971
# getting item 11763
# getting item 12351
# getting item 9330
# getting item 508
# getting item 10563
# getting item 12638
# getting item 2718
# getting item 7400
# getting item 5906
# getting item 5893
# getting item 6922
# getting item 12437
# getting item 12138
# getting item 2715
# getting item 7027
# getting item 2239
# getting item 4435
# getting item 6160
# getting item 729
# getting item 14405
# getting item 3150
# getting item 2595
# getting item 3266
# getting item 6001
# getting item 6226
# getting item 2554
# getting item 10953
# getting item 2604
# getting item 11278
# getting item 12153
# getting item 12542
# getting item 13516
# getting item 9524
# getting item 12096
# getting item 12758
# getting item 15487
# getting item 4230
# getting item 7883
# getting item 11684
# getting item 3867
# getting item 12749
# getting item 1162
# getting item 10967
# getting item 5079
# getting item 195
# getting item 3129
# getting item 11683
# getting item 291
# getting item 8488
# getting item 12630
# getting item 15439
# getting item 5818
# getting item 3228
# getting item 10429
# getting item 12718
# getting item 1039
# getting item 8328
# getting item 1306
# getting item 14030
# getting item 14053
# getting item 7624
# getting item 150
# getting item 2467
# getting item 9634
# getting item 5460
# getting item 6057
# getting item 4268
# getting item 14094
# getting item 9199
# getting item 5022
# getting item 8733
# getting item 11285
# getting item 10121
# getting item 8300
# getting item 12601
# getting item 213
# getting item 4250
# getting item 14106
# getting item 14208
# getting item 6464
# getting item 7653
# getting item 6937
# getting item 10575
# getting item 9811
# getting item 2768
# getting item 9280
# getting item 3593
# getting item 5970
# getting item 1960
# getting item 1970
# getting item 7365
# getting item 12027
# getting item 1148
# getting item 9293
# getting item 14184
# getting item 12992
# getting item 15093
# getting item 8736
# getting item 3274
# getting item 314
# getting item 8086
# getting item 4417
# getting item 13243
# getting item 5939
# getting item 384
# getting item 8085
# getting item 6738
# getting item 11473
# getting item 13377
# getting item 15445
# getting item 5572
# getting item 13930
# getting item 8775
# getting item 5350
# getting item 13504
# getting item 1782
# getting item 4094
# getting item 1153
# getting item 13889
# getting item 6046
# getting item 13334
# getting item 4464
# getting item 6726
# getting item 11813
# getting item 2547
# getting item 11048
# getting item 15341
# getting item 9837
# getting item 15168
# getting item 9632
# getting item 12050
# getting item 8932
# getting item 10840
# getting item 279
# getting item 2165
# getting item 5288
# getting item 5131
# getting item 5238
# getting item 8151
# getting item 4108
# getting item 3553
# getting item 2585
# getting item 9294
# getting item 13912
# getting item 1016
# getting item 2111
# getting item 3616
# getting item 2705
# getting item 1122
# getting item 12860
# getting item 5370
# getting item 3661
# getting item 593
# getting item 14610
# getting item 13169
# getting item 6074
# getting item 15540
# getting item 2931
# getting item 2756
# getting item 2803
# getting item 4812
# getting item 9286
# getting item 13363
# getting item 2668
# getting item 1451
# getting item 7537
# getting item 1456
# getting item 2216
# getting item 10905
# getting item 1905
# getting item 12933
# getting item 11401
# getting item 3493
# getting item 11907
# getting item 3800
# getting item 5641
# getting item 14475
# getting item 9921
# getting item 9230
# getting item 1989
# getting item 6929
# getting item 6817
# getting item 8955
# getting item 13895
# getting item 8534
# getting item 3193
# getting item 12302
# getting item 12669
# getting item 2517
# getting item 2868
# getting item 746
# getting item 9157
# getting item 5597
# getting item 9749
# getting item 9218
# getting item 2746
# getting item 1553
# getting item 7152
# getting item 11720
# getting item 9711
# getting item 5604
# getting item 886
# getting item 10298
# getting item 8705
# getting item 6342
# getting item 948
# getting item 10068
# getting item 14458
# getting item 1410
# getting item 7340
# getting item 6051
# getting item 11370
# getting item 592
# getting item 4285
# getting item 5092
# getting item 11071
# getting item 11854
# getting item 12764
# getting item 7488
# getting item 3005
# getting item 1920
# getting item 5026
# getting item 4698
# getting item 14686
# getting item 7155
# getting item 10061
# getting item 15581
# getting item 1987
# getting item 4828
# getting item 3158
# getting item 1320
# getting item 6478
# getting item 4302
# getting item 9810
# getting item 9596
# getting item 12426
# getting item 8163
# getting item 11547
# getting item 5224
# getting item 13587
# getting item 5213
# getting item 3770
# getting item 9393
# getting item 8984
# getting item 3490
# getting item 50
# getting item 14649
# getting item 7828
# getting item 1390
# getting item 2613
# getting item 9569
# getting item 14034
# getting item 7945
# getting item 8415
# getting item 7383
# getting item 11356
# getting item 8978
# getting item 10107
# getting item 477
# getting item 13613
# getting item 14961
# getting item 15005
# getting item 1409
# getting item 12947
# getting item 14941
# getting item 1108
# getting item 201
# getting item 13268
# getting item 5234
# getting item 5212
# getting item 928
# getting item 9730
# getting item 3013
# getting item 10593
# getting item 10015
# getting item 11299
# getting item 4098
# getting item 2784
# getting item 7124
# getting item 8893
# getting item 15070
# getting item 648
# getting item 3591
# getting item 8481
# getting item 9919
# getting item 1816
# getting item 12068
# getting item 14387
# getting item 12906
# getting item 13969
# getting item 5393
# getting item 11942
# getting item 10074
# getting item 3349
# getting item 11841
# getting item 10243
# getting item 1571
# getting item 6385
# getting item 14778
# getting item 10375
# getting item 174
# getting item 9172
# getting item 13227
# getting item 14127
# getting item 10590
# getting item 2556
# getting item 13864
# getting item 3472
# getting item 4378
# getting item 1287
# getting item 11595
# getting item 15000
# getting item 12861
# getting item 9566
# getting item 10732
# getting item 9806
# getting item 5087
# getting item 1833
# getting item 10294
# getting item 1211
# getting item 10913
# getting item 8567
# getting item 9345
# getting item 10730
# getting item 4690
# getting item 6591
# getting item 3031
# getting item 10932
# getting item 14469
# getting item 15458
# getting item 15165
# getting item 11952
# getting item 4672
# getting item 1914
# getting item 4722
# getting item 12637
# getting item 8522
# getting item 797
# getting item 6787
# getting item 9664
# getting item 9724
# getting item 5578
# getting item 10656
# getting item 12419
# getting item 3146
# getting item 962
# getting item 9702
# getting item 3660
# getting item 1284
# getting item 4879
# getting item 718
# getting item 6050
# getting item 8937
# getting item 6312
# getting item 5843
# getting item 8305
# getting item 1470
# getting item 13645
# getting item 8818
# getting item 2418
# getting item 5469
# getting item 8055
# getting item 12170
# getting item 11116
# getting item 4088
# getting item 7112
# getting item 2199
# getting item 10425
# getting item 5610
# getting item 10156
# getting item 6987
# getting item 14114
# getting item 216
# getting item 449
# getting item 3496
# getting item 133
# getting item 14940
# getting item 14853
# getting item 14060
# getting item 4114
# getting item 5673
# getting item 15330
# getting item 1354
# getting item 5314
# getting item 11807
# getting item 5545
# getting item 2673
# getting item 2848
# getting item 13270
# getting item 12243
# getting item 14581
# getting item 10004
# getting item 2315
# getting item 8207
# getting item 14067
# getting item 13204
# getting item 157
# getting item 12244
# getting item 401
# getting item 11980
# getting item 2091
# getting item 3440
# getting item 15585
# getting item 10131
# getting item 6727
# getting item 6086
# getting item 12656
# getting item 5638
# getting item 11326
# getting item 5034
# getting item 2807
# getting item 556
# getting item 11885
# getting item 3951
# getting item 779
# getting item 1926
# getting item 8871
# getting item 2603
# getting item 1342
# getting item 12708
# getting item 3530
# getting item 7127
# getting item 10798
# getting item 8651
# getting item 5126
# getting item 4626
# getting item 6659
# getting item 11505
# getting item 5045
# getting item 4592
# getting item 11449
# getting item 6832
# getting item 271
# getting item 3718
# getting item 8349
# getting item 9134
# getting item 5153
# getting item 7196
# getting item 9573
# getting item 5867
# getting item 14730
# getting item 1625
# getting item 15087
# getting item 3107
# getting item 3737
# getting item 15086
# getting item 15648
# getting item 7002
# getting item 759
# getting item 6867
# getting item 9956
# getting item 2321
# getting item 6683
# getting item 10163
# getting item 14035
# getting item 9871
# getting item 3155
# getting item 12797
# getting item 5416
# getting item 5476
# getting item 7955
# getting item 3605
# getting item 4477
# getting item 1439
# getting item 13670
# getting item 2246
# getting item 3083
# getting item 7582
# getting item 11403
# getting item 10293
# getting item 2079
# getting item 14496
# getting item 2453
# getting item 6997
# getting item 11038
# getting item 13771
# getting item 14860
# getting item 2009
# getting item 5857
# getting item 3354
# getting item 4171
# getting item 8916
# getting item 3683
# getting item 13743
# getting item 12651
# getting item 15600
# getting item 6291
# getting item 8449
# getting item 8703
# getting item 13214
# getting item 7723
# getting item 4616
# getting item 15257
# getting item 14743
# getting item 14250
# getting item 15016
# getting item 4029
# getting item 4757
# getting item 5656
# getting item 2126
# getting item 9181
# getting item 10193
# getting item 8433
# getting item 14328
# getting item 15615
# getting item 8599
# getting item 15145
# getting item 6326
# getting item 9242
# getting item 12484
# getting item 9823
# getting item 7310
# getting item 4618
# getting item 14219
# getting item 7222
# getting item 6091
# getting item 9251
# getting item 7257
# getting item 7491
# getting item 8531
# getting item 10261
# getting item 579
# getting item 3184
# getting item 2375
# getting item 5821
# getting item 809
# getting item 6740
# getting item 12297
# getting item 12145
# getting item 12504
# getting item 293
# getting item 3098
# getting item 13628
# getting item 14815
# getting item 15564
# getting item 12804
# getting item 11705
# getting item 953
# getting item 15597
# getting item 6177
# getting item 13210
# getting item 646
# getting item 4622
# getting item 1174
# getting item 4214
# getting item 12023
# getting item 13957
# getting item 14118
# getting item 2014
# getting item 10739
# getting item 3059
# getting item 1201
# getting item 8682
# getting item 6614
# getting item 2016
# getting item 295
# getting item 8698
# getting item 12688
# getting item 13762
# getting item 1454
# getting item 14561
# getting item 1536
# getting item 4352
# getting item 11520
# getting item 7901
# getting item 13995
# getting item 1464
# getting item 7354
# getting item 2898
# getting item 13080
# getting item 13764
# getting item 1848
# getting item 13972
# getting item 3560
# getting item 2271
# getting item 6512
# getting item 7168
# getting item 2256
# getting item 12454
# getting item 6220
# getting item 2864
# getting item 15004
# getting item 15111
# getting item 12759
# getting item 12051
# getting item 6802
# getting item 9764
# getting item 10570
# getting item 3923
# getting item 11249
# getting item 645
# getting item 6054
# getting item 3924
# getting item 5635
# getting item 8867
# getting item 13770
# getting item 9035
# getting item 7487
# getting item 9780
# getting item 3815
# getting item 1432
# getting item 12867
# getting item 15524
# getting item 10721
# getting item 6388
# getting item 6604
# getting item 7888
# getting item 11893
# getting item 13244
# getting item 7083
# getting item 2681
# getting item 2706
# getting item 3897
# getting item 4312
# getting item 10235
# getting item 12882
# getting item 6427
# getting item 3551
# getting item 7011
# getting item 6459
# getting item 1303
# getting item 3983
# getting item 13206
# getting item 10427
# getting item 12189
# getting item 9099
# getting item 14841
# getting item 11682
# getting item 3035
# getting item 675
# getting item 2637
# getting item 10778
# getting item 8279
# getting item 7481
# getting item 3161
# getting item 12803
# getting item 15350
# getting item 5629
# getting item 10505
# getting item 15159
# getting item 366
# getting item 439
# getting item 6027
# getting item 13553
# getting item 6457
# getting item 975
# getting item 9005
# getting item 5988
# getting item 11895
# getting item 9441
# getting item 8253
# getting item 2055
# getting item 11050
# getting item 8644
# getting item 2041
# getting item 14646
# getting item 15329
# getting item 3299
# getting item 7603
# getting item 2166
# getting item 11328
# getting item 3916
# getting item 2124
# getting item 10813
# getting item 8979
# getting item 6104
# getting item 9716
# getting item 8615
# getting item 5278
# getting item 6415
# getting item 6818
# getting item 11800
# getting item 15390
# getting item 14741
# getting item 4863
# getting item 8211
# getting item 8465
# getting item 2955
# getting item 14700
# getting item 4288
# getting item 6230
# getting item 5441
# getting item 6218
# getting item 3177
# getting item 12079
# getting item 4199
# getting item 4448
# getting item 13632
# getting item 13570
# getting item 9112
# getting item 472
# getting item 8247
# getting item 11760
# getting item 5281
# getting item 9479
# getting item 8962
# getting item 11560
# getting item 15478
# getting item 12298
# getting item 263
# getting item 452
# getting item 2489
# getting item 14021
# getting item 3414
# getting item 6791
# getting item 4944
# getting item 9641
# getting item 2789
# getting item 11161
# getting item 4732
# getting item 1701
# getting item 10250
# getting item 290
# getting item 10741
# getting item 8541
# getting item 9358
# getting item 10562
# getting item 7953
# getting item 8171
# getting item 6044
# getting item 13525
# getting item 13095
# getting item 2030
# getting item 2674
# getting item 14950
# getting item 11333
# getting item 7463
# getting item 14013
# getting item 11847
# getting item 9586
# getting item 297
# getting item 7898
# getting item 5108
# getting item 12414
# getting item 8758
# getting item 4383
# getting item 6417
# getting item 5299
# getting item 14420
# getting item 12264
# getting item 10057
# getting item 8164
# getting item 7392
# getting item 12863
# getting item 13300
# getting item 2574
# getting item 9674
# getting item 833
# getting item 6988
# getting item 7732
# getting item 12014
# getting item 13093
# getting item 6422
# getting item 14736
# getting item 1560
# getting item 13124
# getting item 2638
# getting item 10275
# getting item 14268
# getting item 12935
# getting item 10807
# getting item 11205
# getting item 6246
# getting item 10864
# getting item 11829
# getting item 1983
# getting item 10052
# getting item 14395
# getting item 10205
# getting item 2646
# getting item 1616
# getting item 5139
# getting item 6981
# getting item 5180
# getting item 2950
# getting item 65
# getting item 3621
# getting item 5736
# getting item 3424
# getting item 4385
# getting item 3398
# getting item 12897
# getting item 9110
# getting item 14671
# getting item 11044
# getting item 7327
# getting item 9423
# getting item 703
# getting item 1332
# getting item 14235
# getting item 3608
# getting item 10065
# getting item 12845
# getting item 9680
# getting item 4573
# getting item 14728
# getting item 9460
# getting item 10790
# getting item 1895
# getting item 10576
# getting item 13948
# getting item 2201
# getting item 6025
# getting item 10391
# getting item 15457
# getting item 9126
# getting item 1534
# getting item 6965
# getting item 8132
# getting item 3484
# getting item 130
# getting item 13440
# getting item 3665
# getting item 14533
# getting item 11139
# getting item 12674
# getting item 12810
# getting item 11576
# getting item 5776
# getting item 11335
# getting item 429
# getting item 14584
# getting item 6717
# getting item 8127
# getting item 3674
# getting item 13664
# getting item 12238
# getting item 9337
# getting item 6392
# getting item 744
# getting item 5831
# getting item 14433
# getting item 15332
# getting item 7100
# getting item 9585
# getting item 7695
# getting item 4483
# getting item 1966
# getting item 1346
# getting item 15358
# getting item 531
# getting item 10975
# getting item 4234
# getting item 7474
# getting item 11217
# getting item 10102
# getting item 6798
# getting item 3120
# getting item 5245
# getting item 5223
# getting item 1082
# getting item 11554
# getting item 9458
# getting item 1501
# getting item 7332
# getting item 10831
# getting item 8827
# getting item 6144
# getting item 2748
# getting item 14491
# getting item 4279
# getting item 3896
# getting item 5208
# getting item 7548
# getting item 5754
# getting item 12572
# getting item 537
# getting item 5282
# getting item 13437
# getting item 3761
# getting item 1154
# getting item 14978
# getting item 3668
# getting item 1641
# getting item 2856
# getting item 5552
# getting item 9455
# getting item 11089
# getting item 9082
# getting item 13646
# getting item 2520
# getting item 9271
# getting item 8074
# getting item 11256
# getting item 9642
# getting item 13879
# getting item 13597
# getting item 11934
# getting item 61
# getting item 1896
# getting item 2344
# getting item 1157
# getting item 9122
# getting item 9772
# getting item 3264
# getting item 6351
# getting item 12918
# getting item 10603
# getting item 11556
# getting item 1158
# getting item 9339
# getting item 8635
# getting item 12178
# getting item 7576
# getting item 7396
# getting item 15071
# getting item 1252
# getting item 8282
# getting item 11627
# getting item 9445
# getting item 14227
# getting item 8092
# getting item 10610
# getting item 2411
# getting item 9770
# getting item 6853
# getting item 11911
# getting item 4636
# getting item 1705
# getting item 3444
# getting item 10715
# getting item 5775
# getting item 9855
# getting item 14190
# getting item 6960
# getting item 12675
# getting item 10775
# getting item 14452
# getting item 1238
# getting item 14131
# getting item 12064
# getting item 2838
# getting item 10049
# getting item 14109
# getting item 3839
# getting item 6887
# getting item 11946
# getting item 13917
# getting item 6056
# getting item 8427
# getting item 10268
# getting item 8985
# getting item 1570
# getting item 11512
# getting item 5141
# getting item 5367
# getting item 738
# getting item 12287
# getting item 4537
# getting item 3932
# getting item 12220
# getting item 748
# getting item 9270
# getting item 14046
# getting item 7314
# getting item 4911
# getting item 8468
# getting item 5341
# getting item 4746
# getting item 11968
# getting item 11
# getting item 802
# getting item 6241
# getting item 10719
# getting item 11227
# getting item 10259
# getting item 7934
# getting item 8585
# getting item 3253
# getting item 11157
# getting item 5783
# getting item 2910
# getting item 7916
# getting item 2338
# getting item 5449
# getting item 11566
# getting item 2513
# getting item 9340
# getting item 2084
# getting item 3806
# getting item 11007
# getting item 12074
# getting item 10297
# getting item 8832
# getting item 10676
# getting item 12132
# getting item 10622
# getting item 10868
# getting item 9935
# getting item 7581
# getting item 1638
# getting item 13510
# getting item 11422
# getting item 3244
# getting item 5134
# getting item 1977
# getting item 1106
# getting item 13985
# getting item 11430
# getting item 12568
# getting item 13247
# getting item 6116
# getting item 13583
# getting item 10428
# getting item 14680
# getting item 11540
# getting item 8836
# getting item 10106
# getting item 5876
# getting item 13550
# getting item 13202
# getting item 12435
# getting item 4053
# getting item 15204
# getting item 1546
# getting item 1830
# getting item 7525
# getting item 6430
# getting item 323
# getting item 7583
# getting item 6038
# getting item 12059
# getting item 139
# getting item 8849
# getting item 15184
# getting item 10045
# getting item 15260
# getting item 14124
# getting item 6493
# getting item 3054
# getting item 13531
# getting item 10424
# getting item 6784
# getting item 7052
# getting item 8326
# getting item 8931
# getting item 15667
# getting item 14289
# getting item 11872
# getting item 14555
# getting item 9142
# getting item 3928
# getting item 3763
# getting item 5348
# getting item 13423
# getting item 1131
# getting item 13321
# getting item 7631
# getting item 9017
# getting item 7342
# getting item 8824
# getting item 4330
# getting item 4420
# getting item 13506
# getting item 1811
# getting item 12563
# getting item 426
# getting item 4711
# getting item 14474
# getting item 1675
# getting item 5949
# getting item 7716
# getting item 1548
# getting item 12384
# getting item 5992
# getting item 3669
# getting item 12921
# getting item 10834
# getting item 3691
# getting item 8711
# getting item 11204
# getting item 12793
# getting item 4595
# getting item 5810
# getting item 9063
# getting item 2669
# getting item 15258
# getting item 14986
# getting item 13797
# getting item 15200
# getting item 2827
# getting item 3524
# getting item 4342
# getting item 15611
# getting item 6830
# getting item 625
# getting item 10171
# getting item 13680
# getting item 3996
# getting item 12653
# getting item 9807
# getting item 5311
# getting item 3163
# getting item 7320
# getting item 3449
# getting item 4733
# getting item 6451
# getting item 4076
# getting item 13668
# getting item 6719
# getting item 4708
# getting item 6425
# getting item 13675
# getting item 8316
# getting item 8922
# getting item 9727
# getting item 9396
# getting item 343
# getting item 14997
# getting item 4754
# getting item 10502
# getting item 5850
# getting item 6498
# getting item 9612
# getting item 6733
# getting item 13308
# getting item 6958
# getting item 5028
# getting item 13758
# getting item 11701
# getting item 8892
# getting item 11913
# getting item 7658
# getting item 7442
# getting item 2372
# getting item 11304
# getting item 4421
# getting item 4416
# getting item 9661
# getting item 11661
# getting item 14288
# getting item 5080
# getting item 11944
# getting item 2949
# getting item 10690
# getting item 4212
# getting item 9166
# getting item 1274
# getting item 5437
# getting item 251
# getting item 4426
# getting item 15656
# getting item 14938
# getting item 4740
# getting item 8429
# getting item 5267
# getting item 6809
# getting item 173
# getting item 13163
# getting item 9323
# getting item 4261
# getting item 2029
# getting item 7045
# getting item 1537
# getting item 13621
# getting item 10814
# getting item 4445
# getting item 8139
# getting item 13926
# getting item 9903
# getting item 1825
# getting item 10166
# getting item 10348
# getting item 1807
# getting item 7193
# getting item 9008
# getting item 5654
# getting item 8137
# getting item 14209
# getting item 4577
# getting item 12048
# getting item 6776
# getting item 11534
# getting item 14024
# getting item 12530
# getting item 5025
# getting item 224
# getting item 4346
# getting item 13108
# getting item 1937
# getting item 7578
# getting item 14406
# getting item 324
# getting item 9600
# getting item 9525
# getting item 7770
# getting item 2653
# getting item 4641
# getting item 10769
# getting item 15214
# getting item 12828
# getting item 13575
# getting item 9179
# getting item 14729
# getting item 800
# getting item 8749
# getting item 8101
# getting item 3784
# getting item 10194
# getting item 5203
# getting item 14251
# getting item 488
# getting item 3929
# getting item 10836
# getting item 1605
# getting item 12475
# getting item 1254
# getting item 2771
# getting item 7511
# getting item 15651
# getting item 14381
# getting item 1654
# getting item 13280
# getting item 7981
# getting item 4334
# getting item 2584
# getting item 6243
# getting item 3805
# getting item 4348
# getting item 6238
# getting item 13958
# getting item 10987
# getting item 12286
# getting item 404
# getting item 15384
# getting item 3033
# getting item 11695
# getting item 6108
# getting item 8906
# getting item 14830
# getting item 3864
# getting item 33
# getting item 1627
# getting item 6736
# getting item 3878
# getting item 643
# getting item 5246
# getting item 942
# getting item 2580
# getting item 2296
# getting item 14139
# getting item 12774
# getting item 8768
# getting item 11571
# getting item 9502
# getting item 8612
# getting item 13442
# getting item 5279
# getting item 12405
# getting item 13768
# getting item 5055
# getting item 13079
# getting item 10597
# getting item 5816
# getting item 4739
# getting item 7051
# getting item 8557
# getting item 2313
# getting item 10123
# getting item 11198
# getting item 12765
# getting item 10173
# getting item 8523
# getting item 9798
# getting item 5324
# getting item 7221
# getting item 4620
# getting item 995
# getting item 360
# getting item 7652
# getting item 7744
# getting item 1762
# getting item 1283
# getting item 4934
# getting item 13775
# getting item 3296
# getting item 3702
# getting item 12355
# getting item 7866
# getting item 15105
# getting item 15394
# getting item 3060
# getting item 8210
# getting item 4084
# getting item 6920
# getting item 4115
# getting item 9781
# getting item 2417
# getting item 10213
# getting item 2939
# getting item 5382
# getting item 10392
# getting item 10687
# getting item 11731
# getting item 4148
# getting item 1602
# getting item 13422
# getting item 331
# getting item 1395
# getting item 14396
# getting item 540
# getting item 8344
# getting item 4605
# getting item 15636
# getting item 578
# getting item 9970
# getting item 13557
# getting item 1071
# getting item 5534
# getting item 11254
# getting item 13188
# getting item 2295
# getting item 12421
# getting item 2353
# getting item 9347
# getting item 12510
# getting item 454
# getting item 3235
# getting item 15192
# getting item 8650
# getting item 10082
# getting item 8831
# getting item 6837
# getting item 15101
# getting item 7190
# getting item 9093
# getting item 2397
# getting item 3550
# getting item 4943
# getting item 4467
# getting item 4543
# getting item 6697
# getting item 4506
# getting item 8159
# getting item 1299
# getting item 13891
# getting item 9310
# getting item 6969
# getting item 7640
# getting item 7663
# getting item 3230
# getting item 6248
# getting item 9029
# getting item 12267
# getting item 15348
# getting item 13179
# getting item 12812
# getting item 3134
# getting item 11580
# getting item 8583
# getting item 3049
# getting item 11397
# getting item 9867
# getting item 4184
# getting item 450
# getting item 2615
# getting item 11162
# getting item 15133
# getting item 256
# getting item 8572
# getting item 9983
# getting item 9653
# getting item 11340
# getting item 5027
# getting item 7230
# getting item 12713
# getting item 10600
# getting item 504
# getting item 5712
# getting item 1840
# getting item 15306
# getting item 10754
# getting item 10369
# getting item 3818
# getting item 6813
# getting item 11295
# getting item 3222
# getting item 14900
# getting item 12731
# getting item 1297
# getting item 166
# getting item 1259
# getting item 86
# getting item 5106
# getting item 15375
# getting item 9101
# getting item 13438
# getting item 7743
# getting item 941
# getting item 3087
# getting item 7265
# getting item 8611
# getting item 13914
# getting item 9252
# getting item 8031
# getting item 14297
# getting item 11662
# getting item 13024
# getting item 6066
# getting item 13694
# getting item 2075
# getting item 9237
# getting item 13023
# getting item 3233
# getting item 13379
# getting item 4663
# getting item 13452
# getting item 2648
# getting item 7698
# getting item 14112
# getting item 12757
# getting item 9081
# getting item 3570
# getting item 9046
# getting item 10140
# getting item 5353
# getting item 7288
# getting item 3345
# getting item 14884
# getting item 8245
# getting item 3961
# getting item 13271
# getting item 11317
# getting item 11969
# getting item 11107
# getting item 1892
# getting item 10959
# getting item 14343
# getting item 2697
# getting item 2701
# getting item 15229
# getting item 9799
# getting item 2333
# getting item 15129
# getting item 14459
# getting item 14632
# getting item 11395
# getting item 8564
# getting item 7250
# getting item 11329
# getting item 14232
# getting item 12105
# getting item 12842
# getting item 12962
# getting item 11883
# getting item 14057
# getting item 1360
# getting item 8853
# getting item 1110
# getting item 9509
# getting item 7574
# getting item 9537
# getting item 14665
# getting item 7013
# getting item 8950
# getting item 12152
# getting item 3765
# getting item 10961
# getting item 12102
# getting item 8337
# getting item 12623
# getting item 6216
# getting item 14002
# getting item 1044
# getting item 9930
# getting item 13476
# getting item 10523
# getting item 14921
# getting item 8555
# getting item 1496
# getting item 12188
# getting item 10910
# getting item 14617
# getting item 14313
# getting item 14370
# getting item 2202
# getting item 9443
# getting item 13827
# getting item 15660
# getting item 12278
# getting item 15440
# getting item 14779
# getting item 11074
# getting item 8320
# getting item 11579
# getting item 4102
# getting item 9165
# getting item 8242
# getting item 9548
# getting item 9277
# getting item 1949
# getting item 1087
# getting item 9219
# getting item 2503
# getting item 2801
# getting item 3704
# getting item 12580
# getting item 5854
# getting item 8717
# getting item 255
# getting item 5095
# getting item 9681
# getting item 12520
# getting item 4492
# getting item 12600
# getting item 5352
# getting item 7292
# getting item 13883
# getting item 11759
# getting item 6439
# getting item 10021
# getting item 7921
# getting item 5524
# getting item 2478
# getting item 13411
# getting item 13751
# getting item 10497
# getting item 5763
# getting item 3984
# getting item 13606
# getting item 777
# getting item 14903
# getting item 4165
# getting item 13981
# getting item 7950
# getting item 5896
# getting item 15077
# getting item 2550
# getting item 10489
# getting item 3480
# getting item 13443
# getting item 7641
# getting item 8467
# getting item 8401
# getting item 9351
# getting item 12524
# getting item 1716
# getting item 3199
# getting item 6090
# getting item 5369
# getting item 5658
# getting item 451
# getting item 7678
# getting item 7378
# getting item 11405
# getting item 6546
# getting item 8570
# getting item 13745
# getting item 10321
# getting item 2394
# getting item 7961
# getting item 5564
# getting item 12173
# getting item 12794
# getting item 3063
# getting item 5121
# getting item 2961
# getting item 13905
# getting item 12166
# getting item 2235
# getting item 11922
# getting item 3980
# getting item 316
# getting item 4889
# getting item 13269
# getting item 8653
# getting item 3257
# getting item 7890
# getting item 14920
# getting item 11019
# getting item 3714
# getting item 13935
# getting item 9800
# getting item 1559
# getting item 9624
# getting item 12367
# getting item 15043
# getting item 13071
# getting item 5901
# getting item 2628
# getting item 15134
# getting item 1744
# getting item 12786
# getting item 9529
# getting item 9891
# getting item 10423
# getting item 13938
# getting item 4282
# getting item 8038
# getting item 10833
# getting item 13098
# getting item 8586
# getting item 12884
# getting item 14479
# getting item 4074
# getting item 8619
# getting item 5189
# getting item 12532
# getting item 2534
# getting item 530
# getting item 3178
# getting item 5346
# getting item 10054
# getting item 8113
# getting item 15378
# getting item 3475
# getting item 14810
# getting item 9492
# getting item 14509
# getting item 12777
# getting item 11155
# getting item 12075
# getting item 1002
# getting item 15360
# getting item 13978
# getting item 4700
# getting item 8267
# getting item 12874
# getting item 6099
# getting item 1301
# getting item 2516
# getting item 5585
# getting item 7165
# getting item 2378
# getting item 4126
# getting item 8441
# getting item 15182
# getting item 13513
# getting item 11697
# getting item 7016
# getting item 11753
# getting item 705
# getting item 1563
# getting item 12672
# getting item 3286
# getting item 4232
# getting item 7988
# getting item 12581
# getting item 13087
# getting item 12576
# getting item 6882
# getting item 11173
# getting item 9279
# getting item 11857
# getting item 4748
# getting item 3290
# getting item 14891
# getting item 14855
# getting item 2514
# getting item 9375
# getting item 2252
# getting item 11826
# getting item 8714
# getting item 6477
# getting item 14612
# getting item 10991
# getting item 2858
# getting item 2551
# getting item 15164
# getting item 11782
# getting item 11004
# getting item 982
# getting item 14213
# getting item 10042
# getting item 14048
# getting item 5498
# getting item 3010
# getting item 12754
# getting item 2305
# getting item 13455
# getting item 6317
# getting item 7763
# getting item 14032
# getting item 11967
# getting item 3040
# getting item 13147
# getting item 3289
# getting item 8671
# getting item 7135
# getting item 3525
# getting item 1633
# getting item 3627
# getting item 7159
# getting item 15256
# getting item 4393
# getting item 10266
# getting item 10274
# getting item 2237
# getting item 7341
# getting item 7418
# getting item 2845
# getting item 15190
# getting item 11052
# getting item 3635
# getting item 14726
# getting item 6842
# getting item 3910
# getting item 4390
# getting item 3610
# getting item 4987
# getting item 4484
# getting item 1870
# getting item 13229
# getting item 12552
# getting item 11243
# getting item 8398
# getting item 12849
# getting item 1883
# getting item 8656
# getting item 13337
# getting item 14305
# getting item 7854
# getting item 13778
# getting item 10916
# getting item 12954
# getting item 10343
# getting item 4255
# getting item 7729
# getting item 14546
# getting item 10609
# getting item 6337
# getting item 13802
# getting item 3325
# getting item 15583
# getting item 123
# getting item 3959
# getting item 14587
# getting item 1391
# getting item 9333
# getting item 9350
# getting item 4197
# getting item 2136
# getting item 12911
# getting item 12339
# getting item 8986
# getting item 2640
# getting item 8951
# getting item 6045
# getting item 656
# getting item 12909
# getting item 12013
# getting item 5104
# getting item 12824
# getting item 1098
# getting item 10512
# getting item 1651
# getting item 2362
# getting item 8947
# getting item 13138
# getting item 1176
# getting item 6349
# getting item 9945
# getting item 1264
# getting item 1060
# getting item 9425
# getting item 6653
# getting item 4167
# getting item 8028
# getting item 14159
# getting item 2149
# getting item 2343
# getting item 4388
# getting item 3337
# getting item 1422
# getting item 8443
# getting item 15110
# getting item 2712
# getting item 6003
# getting item 11538
# getting item 14640
# getting item 14333
# getting item 14354
# getting item 7588
# getting item 4953
# getting item 3620
# getting item 11062
# getting item 14081
# getting item 4337
# getting item 13913
# getting item 15586
# getting item 13290

# %% [markdown]
# Построим кривые обучения

# %%
loss, acc, val_loss, val_acc = zip(*history)

# %%
plt.figure(figsize=(15, 9))
plt.plot(loss, label="train_loss")
plt.plot(val_loss, label="val_loss")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ### Ну и что теперь со всем этим делать?

# %% [markdown]
# ![alt text](https://www.indiewire.com/wp-content/uploads/2014/08/the-simpsons.jpg)

# %% [markdown]
# Хорошо бы понять, как сделать сабмит.
# У нас есть сеть и методы eval у нее, которые позволяют перевести сеть в режим предсказания. Стоит понимать, что у нашей модели на последнем слое стоит softmax, которые позволяет получить вектор вероятностей  того, что объект относится к тому или иному классу. Давайте воспользуемся этим.

# %%
def predict_one_sample(model, inputs, device=DEVICE):
    """Предсказание, для одной картинки"""
    with torch.no_grad():
        inputs = inputs.to(device)
        model.eval()
        logit = model(inputs).cpu()
        probs = torch.nn.functional.softmax(logit, dim=-1).numpy()
    return probs

# %%
idxs = np.random.randint(0, 1000, 2)
subset = torch.utils.data.Subset(val_dataset, idxs)
loader = torch.utils.data.DataLoader(subset, batch_size=len(subset))
samples = next(iter(loader))[0]
display(samples[0])
probs = predict_one_sample(simple_cnn, samples, device=torch.device("cpu"))
len(probs)
probs.shape
# Out:
# tensor([[[-0.0629, -0.0629, -0.0629,  ..., -0.0629, -0.0629, -0.0629],
#          [-0.0629, -0.0629, -0.0629,  ..., -0.0629, -0.0629, -0.0629],
#          [-0.0629, -0.0629, -0.0629,  ..., -0.0629, -0.0629, -0.0629],
#          ...,
#          [-1.6042, -1.6042, -1.6042,  ..., -1.6042, -1.6042, -1.6042],
#          [-1.6042, -1.6042, -1.6042,  ..., -1.6042, -1.6042, -1.6042],
#          [-1.6042, -1.6042, -1.6042,  ..., -1.6042, -1.6042, -1.6042]],
#
#         [[-0.6877, -0.6877, -0.6877,  ..., -0.6877, -0.6877, -0.6877],
#          [-0.6877, -0.6877, -0.6877,  ..., -0.6877, -0.6877, -0.6877],
#          [-0.6877, -0.6877, -0.6877,  ..., -0.6877, -0.6877, -0.6877],
#          ...,
#          [ 0.0476,  0.0476,  0.0476,  ...,  0.0476,  0.0476,  0.0476],
#          [ 0.0476,  0.0476,  0.0476,  ...,  0.0476,  0.0476,  0.0476],
#          [ 0.0476,  0.0476,  0.0476,  ...,  0.0476,  0.0476,  0.0476]],
#
#         [[-1.2467, -1.2467, -1.2467,  ..., -1.2467, -1.2467, -1.2467],
#          [-1.2467, -1.2467, -1.2467,  ..., -1.2467, -1.2467, -1.2467],
#          [-1.2467, -1.2467, -1.2467,  ..., -1.2467, -1.2467, -1.2467],
#          ...,
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#          [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]])
# array([[0.02461144, 0.02353337, 0.02395697, 0.02381514, 0.02280287,
#         0.02342496, 0.02415046, 0.02345312, 0.02393203, 0.02352677,
#         0.0237775 , 0.02279454, 0.02421544, 0.02464828, 0.02370622,
#         0.02404978, 0.02468567, 0.02264827, 0.02335753, 0.02501488,
#         0.0239228 , 0.02404081, 0.02360536, 0.02371863, 0.02370352,
#         0.02479624, 0.02353371, 0.02355617, 0.02249242, 0.02397485,
#         0.02401424, 0.02293254, 0.02511966, 0.02491885, 0.02311892,
#         0.02463398, 0.02251123, 0.02323556, 0.0238058 , 0.02407968,
#         0.02485427, 0.0233254 ],
#        [0.02449006, 0.02342555, 0.02415897, 0.02370605, 0.02316209,
#         0.02344709, 0.02444578, 0.02319632, 0.02397861, 0.02346779,
#         0.02380328, 0.02294997, 0.0243605 , 0.02449595, 0.02333743,
#         0.02377987, 0.02455667, 0.02252983, 0.02340747, 0.02506138,
#         0.02425057, 0.02445642, 0.02355757, 0.02370499, 0.02391801,
#         0.02506842, 0.02319174, 0.02356607, 0.02248802, 0.0238818 ,
#         0.02379024, 0.02286233, 0.0251318 , 0.02477715, 0.0227872 ,
#         0.02469456, 0.02286371, 0.02314541, 0.02396303, 0.02378588,
#         0.02500041, 0.02335397]], dtype=float32)

# %%
random_characters = int(np.random.uniform(0,1000))
ex_img, true_label = val_dataset[random_characters]
probs_im = predict_one_sample(simple_cnn, ex_img.unsqueeze(0))

# %%
idxs = list(map(int, np.random.uniform(0,1000, 20)))
imgs = [val_dataset[id][0].unsqueeze(0) for id in idxs]

probs_ims = predict(simple_cnn, imgs)

# %%
label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

# %%
y_pred = np.argmax(probs_ims,-1)

actual_labels = [val_dataset[id][1] for id in idxs]

preds_class = [label_encoder.classes_[i] for i in y_pred]

# %%
type([(i**2 for i in range(5))])
# Out:
# list

# %% [markdown]
# Обратите внимание, что метрика, которую необходимо оптимизировать в конкурсе --- f1-score. Вычислим целевую метрику на валидационной выборке.

# %%
from sklearn.metrics import f1_score

f1_score(actual_labels, preds_class)

# %% [markdown]
# Сделаем классную визуализацию,  чтобы посмотреть насколько сеть уверена в своих ответах. Можете исспользовать это, чтобы отлаживать правильность вывода.

# %%
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(12, 12), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    
    

    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
    
    actual_text = "Actual : {}".format(img_label)
            
    fig_x.add_patch(patches.Rectangle((0, 53),86,35,color='white'))
    font0 = FontProperties()
    font = font0.copy()
    font.set_family("fantasy")
    prob_pred = predict_one_sample(simple_cnn, im_val.unsqueeze(0))
    predicted_proba = np.max(prob_pred)*100
    y_pred = np.argmax(prob_pred)
    
    predicted_label = label_encoder.classes_[y_pred]
    predicted_label = predicted_label[:len(predicted_label)//2] + '\n' + predicted_label[len(predicted_label)//2:]
    predicted_text = "{} : {:.0f}%".format(predicted_label,predicted_proba)
            
    fig_x.text(1, 59, predicted_text , horizontalalignment='left', fontproperties=font,
                    verticalalignment='top',fontsize=8, color='black',fontweight='bold')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['fantasy'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Попробуйте найти те классы, которые сеть не смогла расспознать. Изучите данную проблему, это понадобится в дальнейшем.

# %% [markdown]
# ### Submit на Kaggle

# %% [markdown]
# ![alt text](https://i.redd.it/nuaphfioz0211.jpg)

# %%
test_dataset = SimpsonsDataset(test_files, mode="test")
test_loader = DataLoader(val_dataset, shuffle=False, batch_size=64)
print(next(iter(test_loader))[0])
pass
probs = predict(simple_cnn, test_loader)


preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]
# Out:
# tensor([[[[-0.7993, -0.7993, -0.7993,  ..., -0.1486, -0.1657, -0.1143],
#           [-0.4397, -0.4397, -0.4397,  ...,  0.2624,  0.2967,  0.2796],
#           [-0.2856, -0.2856, -0.2856,  ...,  0.2967,  0.2453,  0.3138],
#           ...,
#           [-0.8678, -0.8678, -0.8678,  ...,  0.3823,  0.3823,  0.3823],
#           [-0.8678, -0.8678, -0.8678,  ...,  0.7419,  0.7419,  0.7419],
#           [-0.8678, -0.8678, -0.8678,  ...,  0.5193,  0.5193,  0.5193]],
#
#          [[-1.1429, -1.1429, -1.1429,  ..., -1.1253, -1.1429, -1.1078],
#           [-0.7752, -0.7752, -0.7752,  ..., -0.7052, -0.6702, -0.6877],
#           [-0.6176, -0.6176, -0.6176,  ..., -0.6352, -0.6877, -0.6527],
#           ...,
#           [-0.6352, -0.6352, -0.6352,  ...,  0.6779,  0.6779,  0.6779],
#           [-0.6352, -0.6352, -0.6352,  ...,  0.9055,  0.9055,  0.9055],
#           [-0.6352, -0.6352, -0.6352,  ...,  0.5903,  0.5903,  0.5903]],
#
#          [[-0.0964, -0.0964, -0.0964,  ..., -0.6018, -0.6193, -0.5844],
#           [ 0.2696,  0.2696,  0.2696,  ..., -0.1835, -0.1487, -0.1661],
#           [ 0.4265,  0.4265,  0.4265,  ..., -0.1312, -0.1835, -0.1312],
#           ...,
#           [ 0.8448,  0.8448,  0.8448,  ...,  0.8448,  0.8448,  0.8448],
#           [ 0.8448,  0.8448,  0.8448,  ...,  0.9842,  0.9842,  0.9842],
#           [ 0.8448,  0.8448,  0.8448,  ...,  0.6531,  0.6531,  0.6531]]],
#
#
#         [[[-1.2959, -1.2959, -1.2959,  ..., -0.4911, -0.4911, -0.4911],
#           [-1.2959, -1.2959, -1.2959,  ..., -0.4397, -0.4397, -0.4397],
#           [-1.2959, -1.2959, -1.2959,  ..., -0.3198, -0.3198, -0.3198],
#           ...,
#           [-1.9809, -1.9809, -1.9809,  ..., -1.9809, -1.9809, -1.9809],
#           [-1.9809, -1.9809, -1.9809,  ..., -1.9809, -1.9809, -1.9809],
#           [-1.9809, -1.9809, -1.9809,  ..., -1.9809, -1.9809, -1.9809]],
#
#          [[ 0.1702,  0.1702,  0.1702,  ..., -2.0357, -2.0357, -2.0357],
#           [ 0.1702,  0.1702,  0.1702,  ..., -2.0357, -2.0357, -2.0357],
#           [ 0.1702,  0.1702,  0.1702,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [ 0.3277,  0.3277,  0.3277,  ...,  0.3277,  0.3277,  0.3277],
#           [ 0.3277,  0.3277,  0.3277,  ...,  0.3277,  0.3277,  0.3277],
#           [ 0.3277,  0.3277,  0.3277,  ...,  0.3277,  0.3277,  0.3277]],
#
#          [[ 1.1934,  1.1934,  1.1934,  ..., -0.2010, -0.2010, -0.2010],
#           [ 1.1934,  1.1934,  1.1934,  ..., -0.2010, -0.2010, -0.2010],
#           [ 1.1934,  1.1934,  1.1934,  ..., -0.1835, -0.1835, -0.1835],
#           ...,
#           [ 0.0779,  0.0779,  0.0779,  ...,  0.0779,  0.0779,  0.0779],
#           [ 0.0779,  0.0779,  0.0779,  ...,  0.0779,  0.0779,  0.0779],
#           [ 0.0779,  0.0779,  0.0779,  ...,  0.0779,  0.0779,  0.0779]]],
#
#
#         [[[-0.3883, -0.3883, -0.3883,  ..., -0.8849, -0.8849, -0.8849],
#           [-0.3883, -0.3883, -0.3883,  ..., -0.5938, -0.5938, -0.5938],
#           [-0.3883, -0.3883, -0.3883,  ..., -0.9877, -0.9877, -0.9877],
#           ...,
#           [-0.0972, -0.0972, -0.0972,  ...,  0.1597,  0.1597,  0.1597],
#           [-0.0972, -0.0972, -0.0972,  ...,  0.1597,  0.1597,  0.1597],
#           [-0.0972, -0.0972, -0.0972,  ...,  0.1597,  0.1597,  0.1597]],
#
#          [[ 0.1176,  0.1176,  0.1176,  ..., -0.3550, -0.3550, -0.3550],
#           [ 0.1176,  0.1176,  0.1176,  ..., -0.0574, -0.0574, -0.0574],
#           [ 0.1176,  0.1176,  0.1176,  ..., -0.4601, -0.4601, -0.4601],
#           ...,
#           [ 0.3978,  0.3978,  0.3978,  ...,  0.6779,  0.6779,  0.6779],
#           [ 0.3978,  0.3978,  0.3978,  ...,  0.6779,  0.6779,  0.6779],
#           [ 0.3978,  0.3978,  0.3978,  ...,  0.6779,  0.6779,  0.6779]],
#
#          [[ 1.3502,  1.3502,  1.3502,  ...,  0.7054,  0.7054,  0.7054],
#           [ 1.3502,  1.3502,  1.3502,  ...,  1.0017,  1.0017,  1.0017],
#           [ 1.3502,  1.3502,  1.3502,  ...,  0.6008,  0.6008,  0.6008],
#           ...,
#           [ 1.3677,  1.3677,  1.3677,  ...,  1.5420,  1.5420,  1.5420],
#           [ 1.3677,  1.3677,  1.3677,  ...,  1.5420,  1.5420,  1.5420],
#           [ 1.3677,  1.3677,  1.3677,  ...,  1.5420,  1.5420,  1.5420]]],
#
#
#         ...,
#
#
#         [[[ 1.3413,  1.3413,  1.3413,  ...,  1.2728,  1.2728,  1.2728],
#           [ 1.3413,  1.3413,  1.3413,  ...,  1.2728,  1.2728,  1.2728],
#           [ 1.3413,  1.3413,  1.3413,  ...,  1.2728,  1.2728,  1.2728],
#           ...,
#           [-0.2513, -0.2513, -0.2513,  ..., -0.3883, -0.3883, -0.3883],
#           [-0.2513, -0.2513, -0.2513,  ..., -0.3883, -0.3883, -0.3883],
#           [-0.2513, -0.2513, -0.2513,  ..., -0.3883, -0.3883, -0.3883]],
#
#          [[ 0.6254,  0.6254,  0.6254,  ...,  0.5553,  0.5553,  0.5553],
#           [ 0.6254,  0.6254,  0.6254,  ...,  0.5553,  0.5553,  0.5553],
#           [ 0.6254,  0.6254,  0.6254,  ...,  0.5553,  0.5553,  0.5553],
#           ...,
#           [-1.3529, -1.3529, -1.3529,  ..., -1.6155, -1.6155, -1.6155],
#           [-1.3529, -1.3529, -1.3529,  ..., -1.6155, -1.6155, -1.6155],
#           [-1.3529, -1.3529, -1.3529,  ..., -1.6155, -1.6155, -1.6155]],
#
#          [[ 0.8622,  0.8622,  0.8622,  ...,  0.7925,  0.7925,  0.7925],
#           [ 0.8622,  0.8622,  0.8622,  ...,  0.7925,  0.7925,  0.7925],
#           [ 0.8622,  0.8622,  0.8622,  ...,  0.7925,  0.7925,  0.7925],
#           ...,
#           [-1.2641, -1.2641, -1.2641,  ..., -1.5604, -1.5604, -1.5604],
#           [-1.2641, -1.2641, -1.2641,  ..., -1.5604, -1.5604, -1.5604],
#           [-1.2641, -1.2641, -1.2641,  ..., -1.5604, -1.5604, -1.5604]]],
#
#
#         [[[-0.1828, -0.1828, -0.1828,  ..., -2.1179, -2.1179, -2.1179],
#           [ 0.3481,  0.3481,  0.3652,  ..., -2.1179, -2.1179, -2.1179],
#           [ 0.5878,  0.5878,  0.6049,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-0.1486, -0.1486, -0.1486,  ..., -2.1179, -2.1179, -2.1008],
#           [-0.0801, -0.0801, -0.0801,  ..., -2.1179, -2.1179, -2.1008],
#           [-1.0219, -1.0219, -1.0219,  ..., -2.1179, -2.1179, -2.1008]],
#
#          [[-0.7927, -0.7927, -0.7927,  ..., -2.0357, -1.9482, -2.0357],
#           [-0.3025, -0.3025, -0.2850,  ..., -2.0357, -1.9482, -2.0357],
#           [-0.1099, -0.1099, -0.0924,  ..., -2.0182, -1.9482, -2.0357],
#           ...,
#           [ 0.5378,  0.5378,  0.5378,  ..., -2.0357, -2.0357, -2.0357],
#           [ 0.6078,  0.6078,  0.6078,  ..., -2.0357, -2.0357, -2.0357],
#           [-0.3550, -0.3550, -0.3550,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.2293, -1.2293, -1.2293,  ..., -1.8044, -1.7870, -1.8044],
#           [-0.7936, -0.7936, -0.7761,  ..., -1.8044, -1.7870, -1.8044],
#           [-0.5844, -0.5844, -0.5670,  ..., -1.8044, -1.7870, -1.8044],
#           ...,
#           [ 0.7054,  0.7054,  0.7054,  ..., -1.8044, -1.8044, -1.8044],
#           [ 0.7751,  0.7751,  0.7751,  ..., -1.8044, -1.8044, -1.8044],
#           [-0.1835, -0.1835, -0.1835,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#         [[[-1.3815, -1.3815, -1.3302,  ..., -1.2103, -1.6555, -1.7925],
#           [ 1.6495,  1.5468,  1.1358,  ...,  0.5707, -0.1999, -0.7479],
#           [ 0.8961,  0.8789,  0.8447,  ...,  0.0741, -0.7650, -1.2617],
#           ...,
#           [-0.6623, -0.6623, -0.6623,  ..., -0.3541, -1.2445, -1.7583],
#           [-0.7822, -0.7822, -0.7822,  ..., -0.0972, -1.0219, -1.6213],
#           [-1.9809, -1.9809, -1.9809,  ..., -1.5357, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -1.6681, -2.0357, -2.0357],
#           [ 0.4328,  0.3277, -0.0924,  ..., -0.0224, -0.7227, -1.2304],
#           [-0.2150, -0.2325, -0.2675,  ..., -0.4251, -1.1604, -1.6506],
#           ...,
#           [ 0.3452,  0.3452,  0.3452,  ...,  0.4853, -0.5301, -1.1078],
#           [ 0.1176,  0.1176,  0.1176,  ...,  0.7129, -0.3901, -1.0028],
#           [-1.1779, -1.1779, -1.1779,  ..., -0.7927, -1.6506, -1.8782]],
#
#          [[-1.5256, -1.5256, -1.4733,  ..., -1.6650, -1.8044, -1.8044],
#           [ 1.6117,  1.5071,  1.1237,  ..., -0.0092, -0.6541, -1.1770],
#           [ 0.8099,  0.7925,  0.7576,  ..., -0.4798, -1.1770, -1.6650],
#           ...,
#           [ 0.4091,  0.4091,  0.4091,  ...,  0.6008, -0.3753, -0.9330],
#           [ 0.2173,  0.2173,  0.2173,  ...,  0.8448, -0.2010, -0.8110],
#           [-1.0550, -1.0550, -1.0550,  ..., -0.6890, -1.4907, -1.7173]]]])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-303-1dd1056851e0> in <module>
#       3 print(next(iter(test_loader))[0])
#       4 pass
# ----> 5 probs = predict(simple_cnn, test_loader)
#       6
#       7
#
# <ipython-input-295-4abaea0b690f> in predict(model, test_loader)
#       4
#       5         for inputs in test_loader:
# ----> 6             inputs = inputs.to(DEVICE)
#       7             model.eval()
#       8             outputs = model(inputs).cpu()
#
# AttributeError: 'list' object has no attribute 'to'

# %%
! ls

# %%
import pandas as pd
my_submit = pd.read_csv("gdrive/My Drive/simpsons/data/labels.csv")
# my_submit = pd.DataFrame({'Image_id': test_filenames, 'Expected': preds})
my_submit.head()

# %%
# TODO : сделайте сабмит (это важно, если Вы не справляетесь, но дошли до этой ячейки, то сообщите в чат и Вам помогут)

# %%
my_submit.to_csv('gdrive/My Drive/simpsons/simple_cnn_baseline.csv', index=False)

# %% [markdown]
# ## Приключение?
#
# А теперь самое интересное, мы сделали простенькую сверточную сеть и смогли отправить сабмит, но получившийся скор нас явно не устраивает. Надо с этим что-то сделать.
#
# Несколько срочныйх улучшейни для нашей сети, которые наверняка пришли Вам в голову:
#
#
# *   Учим дольше и изменяем гиперпараметры сети
# *  learning rate, batch size, нормализация картинки и вот это всё
# *   Кто же так строит нейронные сети? А где пулинги и батч нормы? Надо добавлять
# *  Ну разве Адам наше все? [adamW](https://www.fast.ai/2018/07/02/adam-weight-decay/) для практика, [статейка для любителей](https://openreview.net/pdf?id=ryQu7f-RZ) (очень хороший анализ), [наши ](https://github.com/MichaelKonobeev/adashift/) эксперименты для заинтересованных.
#
# * Ну разве это deep learning? Вот ResNet и Inception, которые можно зафайнтьюнить под наши данные, вот это я понимаю (можно и обучить в колабе, а можно и [готовые](https://github.com/Cadene/pretrained-models.pytorch) скачать).
#
# * Данных не очень много, можно их аугументировать и  доучититься на новом датасете ( который уже будет состоять из, как  пример аугументации, перевернутых изображений)
#
# * Стоит подумать об ансамблях
#
#
# Надеюсь, что у Вас получится!
#
# ![alt text](https://pbs.twimg.com/profile_images/798904974986113024/adcQiVdV.jpg)
